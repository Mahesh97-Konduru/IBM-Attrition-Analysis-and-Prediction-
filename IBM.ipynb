# %% [markdown]
# # Importing the necessery libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats

# %%
data_HR = pd.read_csv('IBM_HR.csv')

# %%
data = data_HR

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # summary statistics

# %%
data.describe().transpose()
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %% [markdown]
# # Target Variable

# %%
# changing the target variable into Binary form
data['Attrition'] = data['Attrition'].replace({'Yes':1,'No':0})

# %%
data['Attrition'].value_counts().plot.bar()

# %%
data['Attrition'].value_counts(normalize = True)
# Out:
# 0    0.838776
# 1    0.161224
# Name: Attrition, dtype: float64

# %% [markdown]
# # Identifying & dropping the useless features

# %%
 data = data.drop(['EmployeeNumber','EmployeeCount','StandardHours'],axis= 1)

# %%
data.shape
# Out:
# (1470, 32)

# %%
count = 0
cat_cols = []
num_cols = []
for num in data.columns:
    if data[num].dtypes == 'O':
        cat_cols.append(num)
        count = count+1
    else:
        num_cols.append(num)

# %%
# count of numeric and categorical coloumns
len(num_cols),len(cat_cols)
# Out:
# (24, 8)

# %% [markdown]
# # identifying the features that has missing values

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %% [markdown]
#     #features doesn't contain any missing values

# %% [markdown]
# # Exploratory data analysis

# %%
def diagnostic_plots(df, variable):
    
    plt.figure(figsize=(16,4))
    
    #histogram
    plt.subplot(1,3,1)
    sns.distplot(df[variable], bins=30)
    
     #q-q plot
    
    plt.subplot(1,3,2)
    stats.probplot(df[variable], dist ='norm', plot = plt)
    
    # box plot
    
    plt.subplot(1,3,3)
    sns.boxplot(y = df[variable])
    plt.show()

# %%
for col in num_cols:
    diagnostic_plots(data,col)
    plt.clf()

# %% [markdown]
# # Ordinal Categories
# [Education,EnvironmentSatisfaction,JobInvolvement,JobLevel,JobSatisfaction,NumCompaniesWorked,
# PerformanceRating,RelationshipSatisfaction,StockOptionLevel,TrainingTimesLastYear,WorkLifeBalance]

# %% [markdown]
# # one hot encoding for categorical features

# %%
data_ohehot = pd.get_dummies(data[cat_cols],drop_first=True)

# %%
data_ohehot
# Out:
#       BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                    0                             1
# 1                                    1                             0
# 2                                    0                             1
# 3                                    1                             0
# 4                                    0                             1
# ...                                ...                           ...
# 1465                                 1                             0
# 1466                                 0                             1
# 1467                                 0                             1
# 1468                                 1                             0
# 1469                                 0                             1
#
#       Department_Research & Development  Department_Sales  \
# 0                                     0                 1
# ...

# %%
data2 = data.drop(cat_cols,axis=1)

# %%
data_new = pd.concat((data_ohehot,data2),axis=1)

# %%
data_new.head()
# Out:
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                 0                             1
# 1                                 1                             0
# 2                                 0                             1
# 3                                 1                             0
# 4                                 0                             1
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# 2                                  1                 0
# 3                                  1                 0
# 4                                  1                 0
#
#    EducationField_Life Sciences  EducationField_Marketing  \
# 0                             1                         0
# 1                             1                         0
# ...

# %% [markdown]
# # Random Forest

# %% [markdown]
# # Without hyper parameter tuning

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score, precision_score
from sklearn.model_selection import GridSearchCV

# %%
X = data_new.drop(columns= ['Attrition'],axis=1)
y = data_new['Attrition']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 10)

# %%
X_train.shape,y_train.shape
# Out:
# ((1029, 44), (1029,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=12)

# %%
# fit the model
model.fit(X_train, y_train)

# Get predictions
y_true, y_pred = y_test, model.predict(X_test)

# Evaluate train and test scores
train_ = model.score(X_train, y_train)
test_ = model.score(X_test, y_test)

# %%
# Other scores
accuracy = accuracy_score(y_true, y_pred).round(3)
            
precision = precision_score(y_true, y_pred).round(3)
            
recall = recall_score(y_true, y_pred).round(3)

# %%
print('-'*20)
print('Training Score: {0:.3f}'.format(train_))
print('Test Score: {0:.3f}'.format(test_))
            
print('Accuracy Score: {0:.3f}'.format(accuracy))
print('Precision Score : {0:.3f}'.format(precision))
print('Recall Score : {0:.3f}'.format(recall))
# Out:
# --------------------
# Training Score: 0.988
# Test Score: 0.846
# Accuracy Score: 0.846
# Precision Score : 0.864
# Recall Score : 0.226

# %% [markdown]
# # with hyper parameter tuning

# %%
# Random Forest Classifier with hyperparameter tuning
model_hyper = RandomForestClassifier()
params = {'n_estimators' : [10, 20, 30, 50, 75, 100], 'max_depth': [1, 2, 3, 5, 7, 10]}

model_grid = GridSearchCV(model_hyper, param_grid = params)

model_grid.fit(X, y)

print(model_grid.best_estimator_)
print(model_grid.best_params_)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=20)
# {'max_depth': 10, 'n_estimators': 20}

# %%
RF_hyper = RandomForestClassifier(max_depth=10,n_estimators=50)

# %%
# fit the model
RF_hyper.fit(X_train, y_train)

# Get predictions
y_true, y_pred = y_test, RF_hyper.predict(X_test)

# Evaluate train and test scores
train_ = RF_hyper.score(X_train, y_train)
test_ = RF_hyper.score(X_test, y_test)

# %%
# Other scores
accuracy = accuracy_score(y_true, y_pred).round(3)
            
precision = precision_score(y_true, y_pred).round(3)
            
recall = recall_score(y_true, y_pred).round(3)

# %%
print('-'*20)
print('Training Score: {0:.3f}'.format(train_))
print('Test Score: {0:.3f}'.format(test_))
            
print('Accuracy Score: {0:.3f}'.format(accuracy))
print('Precision Score : {0:.3f}'.format(precision))
print('Recall Score : {0:.3f}'.format(recall))
# Out:
# --------------------
# Training Score: 0.982
# Test Score: 0.834
# Accuracy Score: 0.834
# Precision Score : 0.824
# Recall Score : 0.167

# %% [markdown]
# # Oversampling

# %%
# Oversampling
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(sampling_strategy = 'minority')
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((1752, 44), (1752,))

# %%
model = RandomForestClassifier(n_estimators=12)

# %%
# fit the model
model.fit(X_train_res, y_train_res)

# Get predictions
y_true, y_pred = y_test, model.predict(X_test)

# Evaluate train and test scores
train_ = model.score(X_train_res, y_train_res)
test_ = model.score(X_test, y_test)

# %%
# Other scores
accuracy = accuracy_score(y_true, y_pred).round(3)
            
precision = precision_score(y_true, y_pred).round(3)
            
recall = recall_score(y_true, y_pred).round(3)

# %%
print('-'*20)
print('Training Score: {0:.3f}'.format(train_))
print('Test Score: {0:.3f}'.format(test_))
            
print('Accuracy Score: {0:.3f}'.format(accuracy))
print('Precision Score : {0:.3f}'.format(precision))
print('Recall Score : {0:.3f}'.format(recall))
# Out:
# --------------------
# Training Score: 0.997
# Test Score: 0.839
# Accuracy Score: 0.839
# Precision Score : 0.697
# Recall Score : 0.274
